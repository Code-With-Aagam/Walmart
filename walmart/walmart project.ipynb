# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('train_walmart.csv')

# %%
features_df = pd.read_csv("features.csv")
stores_df = pd.read_csv("stores.csv")

# %%
train_df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
features_df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
stores_df
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
## inner join
dataset_m = features_df.merge(stores_df,how='inner',on='Store')

# %%
features_df.shape
# Out:
# (8190, 12)

# %%
dataset_m.shape
# Out:
# (8190, 14)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
dataset_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 903.8+ KB

# %%
from datetime import datetime
dataset_m['Date'] = pd.to_datetime(dataset_m['Date'])
train_df['Date'] = pd.to_datetime(train_df['Date'])

# %%
df = train_df.merge(dataset_m, how='inner',on = ['Store','Date','IsHoliday'])

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     2 2010-02-05      50605.27      False        42.31
# 2           1     3 2010-02-05      13740.12      False        42.31
# 3           1     4 2010-02-05      39954.04      False        42.31
# 4           1     5 2010-02-05      32229.38      False        42.31
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    93 2012-10-26       2487.80      False        58.85
# 421566     45    94 2012-10-26       5203.31      False        58.85
# 421567     45    95 2012-10-26      56017.47      False        58.85
# 421568     45    97 2012-10-26       6817.48      False        58.85
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.572        NaN        NaN        NaN        NaN        NaN
# 2            2.572        NaN        NaN        NaN        NaN        NaN
# 3            2.572        NaN        NaN        NaN        NaN        NaN
# 4            2.572        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.882    4018.91      58.08      100.0     211.94     858.33
# 421566       3.882    4018.91      58.08      100.0     211.94     858.33
# 421567       3.882    4018.91      58.08      100.0     211.94     858.33
# 421568       3.882    4018.91      58.08      100.0     211.94     858.33
# 421569       3.882    4018.91      58.08      100.0     211.94     858.33
#
#                CPI  Unemployment Type    Size
# 0       211.096358         8.106    A  151315
# 1       211.096358         8.106    A  151315
# 2       211.096358         8.106    A  151315
# 3       211.096358         8.106    A  151315
# 4       211.096358         8.106    A  151315
# ...            ...           ...  ...     ...
# 421565  192.308899         8.667    B  118221
# 421566  192.308899         8.667    B  118221
# 421567  192.308899         8.667    B  118221
# 421568  192.308899         8.667    B  118221
# 421569  192.308899         8.667    B  118221
#
# [421570 rows x 16 columns]

# %%
df['week'] = df.Date.dt.isocalendar().week

# %%
df['year'] = df.Date.dt.isocalendar().year

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     2 2010-02-05      50605.27      False        42.31
# 2           1     3 2010-02-05      13740.12      False        42.31
# 3           1     4 2010-02-05      39954.04      False        42.31
# 4           1     5 2010-02-05      32229.38      False        42.31
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    93 2012-10-26       2487.80      False        58.85
# 421566     45    94 2012-10-26       5203.31      False        58.85
# 421567     45    95 2012-10-26      56017.47      False        58.85
# 421568     45    97 2012-10-26       6817.48      False        58.85
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.572        NaN        NaN        NaN        NaN        NaN
# 2            2.572        NaN        NaN        NaN        NaN        NaN
# 3            2.572        NaN        NaN        NaN        NaN        NaN
# 4            2.572        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.882    4018.91      58.08      100.0     211.94     858.33
# 421566       3.882    4018.91      58.08      100.0     211.94     858.33
# 421567       3.882    4018.91      58.08      100.0     211.94     858.33
# 421568       3.882    4018.91      58.08      100.0     211.94     858.33
# 421569       3.882    4018.91      58.08      100.0     211.94     858.33
#
#                CPI  Unemployment Type    Size  week  year
# 0       211.096358         8.106    A  151315     5  2010
# 1       211.096358         8.106    A  151315     5  2010
# 2       211.096358         8.106    A  151315     5  2010
# 3       211.096358         8.106    A  151315     5  2010
# 4       211.096358         8.106    A  151315     5  2010
# ...            ...           ...  ...     ...   ...   ...
# 421565  192.308899         8.667    B  118221    43  2012
# 421566  192.308899         8.667    B  118221    43  2012
# 421567  192.308899         8.667    B  118221    43  2012
# 421568  192.308899         8.667    B  118221    43  2012
# 421569  192.308899         8.667    B  118221    43  2012
#
# [421570 rows x 18 columns]

# %%
def scatter(dff,column):
    plt.figure(figsize=(12,8))
    plt.scatter(dff[column],dff['Weekly_Sales'])
    plt.ylabel('weekly sales')
    plt.xlabel(column)

# %%
scatter(df,'Store')

# %%
scatter(df,'Dept')

# %%
df.year.value_counts()
# Out:
# 2011    153453
# 2010    140679
# 2012    127438
# Name: year, dtype: Int64

# %%
weekly_sales_2011 = df[df['year']==2011].groupby(['week'])['Weekly_Sales'].mean()

# %%
weekly_sales_2011
# Out:
# week
# 1     14599.244973
# 2     13891.283484
# 3     13932.367385
# 4     13566.239462
# 5     15773.448776
# 6     16111.706191
# 7     16541.991212
# 8     15049.747558
# 9     15882.557045
# 10    15056.450540
# 11    15216.115961
# 12    14573.827050
# 13    14726.869261
# 14    15634.571312
# 15    15229.708141
# 16    16472.653827
# 17    14745.946064
# 18    15757.215296
# 19    15317.204186
# 20    15002.247279
# 21    15390.233449
# 22    16691.305332
# 23    16302.918830
# 24    16111.226407
# 25    15649.418342
# 26    16232.862334
# 27    16328.646803
# 28    15566.323502
# 29    15526.204180
# 30    14965.150490
# 31    16393.126313
# 32    15774.068626
# 33    15888.028317
# 34    16068.095036
# 35    15387.122167
# 36    15809.069483
# 37    14865.566897
# 38    14446.431089
# 39    14298.824402
# 40    15960.678959
# 41    15062.736015
# 42    15521.325691
# 43    15470.924781
# 44    16471.071192
# 45    16348.811046
# 46    15683.546288
# 47    22043.563476
# 48    16496.511854
# 49    18458.853056
# 50    19942.149333
# 51    25437.146122
# 52    15332.154858
# Name: Weekly_Sales, dtype: float64

# %%
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values,color='red')
# Out:
# <AxesSubplot:xlabel='week'>

# %%
weekly_sales_2010 = df[df['year']==2010].groupby(['week'])['Weekly_Sales'].mean()

# %%
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values)
# Out:
# <AxesSubplot:xlabel='week'>

# %%
weekly_sales_2012 = df[df['year']==2012].groupby(['week'])['Weekly_Sales'].mean()

# %%
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values,color='green')
# Out:
# <AxesSubplot:xlabel='week'>

# %%
plt.figure(figsize=(20,10))
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values)
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values)
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values)
plt.title('Average weekly sales per year')
plt.ylabel('sales')

plt.legend(['2010','2011','2012'])

# %%
sns.distplot(df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %%
sns.boxplot(x = 'Type',y='Size',data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Size'>

# %%
weekly_sales_store = df.groupby(['Store'])['Weekly_Sales'].mean()

# %%
weekly_sales_store.sort_values(ascending=False)
# Out:
# Store
# 20    29508.301592
# 4     29161.210415
# 14    28784.851727
# 13    27355.136891
# 2     26898.070031
# 10    26332.303819
# 27    24826.984536
# 6     21913.243624
# 1     21710.543621
# 39    21000.763562
# 19    20362.126734
# 23    19776.180881
# 31    19681.907464
# 11    19276.762751
# 24    18969.106500
# 28    18714.889803
# 41    17976.004648
# 32    16351.621855
# 18    15733.313136
# 22    15181.218886
# 12    14867.308619
# 26    14554.129672
# 35    13803.596986
# 40    13763.632803
# 34    13522.081671
# 43    13415.114118
# 8     13133.014768
# 17    12954.393636
# 45    11662.897315
# 42    11443.370118
# 21    11283.435496
# 25    10308.157810
# 37    10297.355026
# 15     9002.493073
# 9      8772.890379
# 30     8764.237719
# 36     8584.412563
# 7      8358.766148
# 29     8158.810609
# 16     7863.224124
# 38     7492.478460
# 3      6373.033983
# 44     6038.929814
# 33     5728.414053
# 5      5053.415813
# Name: Weekly_Sales, dtype: float64

# %%
pd.DataFrame(weekly_sales_store).sort_values(by ='Weekly_Sales',ascending=False).style.bar()
# Out:
# <style type="text/css">
# #T_b1c49_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_b1c49_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 98.6%, transparent 98.6%);
# }
# #T_b1c49_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 97.0%, transparent 97.0%);
# }
# #T_b1c49_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 91.2%, transparent 91.2%);
# }
# #T_b1c49_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 89.3%, transparent 89.3%);
# }
# #T_b1c49_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.0%, transparent 87.0%);
# }
# #T_b1c49_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.9%, transparent 80.9%);
# }
# #T_b1c49_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 68.9%, transparent 68.9%);
# }
# #T_b1c49_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 68.1%, transparent 68.1%);
# }
# #T_b1c49_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 65.2%, transparent 65.2%);
# }
# #T_b1c49_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 62.6%, transparent 62.6%);
# }
# #T_b1c49_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 60.2%, transparent 60.2%);
# }
# #T_b1c49_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 59.8%, transparent 59.8%);
# }
# #T_b1c49_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.2%, transparent 58.2%);
# }
# #T_b1c49_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 56.9%, transparent 56.9%);
# }
# #T_b1c49_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 55.9%, transparent 55.9%);
# }
# #T_b1c49_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 52.8%, transparent 52.8%);
# }
# #T_b1c49_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 46.2%, transparent 46.2%);
# }
# #T_b1c49_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 43.7%, transparent 43.7%);
# }
# #T_b1c49_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 41.4%, transparent 41.4%);
# }
# #T_b1c49_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.1%, transparent 40.1%);
# }
# #T_b1c49_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 38.8%, transparent 38.8%);
# }
# #T_b1c49_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.8%, transparent 35.8%);
# }
# #T_b1c49_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.6%, transparent 35.6%);
# }
# #T_b1c49_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.6%, transparent 34.6%);
# }
# #T_b1c49_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.2%, transparent 34.2%);
# }
# #T_b1c49_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.0%, transparent 33.0%);
# }
# #T_b1c49_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.3%, transparent 32.3%);
# }
# #T_b1c49_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 27.0%, transparent 27.0%);
# }
# #T_b1c49_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.1%, transparent 26.1%);
# }
# #T_b1c49_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.5%, transparent 25.5%);
# }
# #T_b1c49_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.5%, transparent 21.5%);
# }
# #T_b1c49_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.4%, transparent 21.4%);
# }
# #T_b1c49_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 16.1%, transparent 16.1%);
# }
# #T_b1c49_row34_col0, #T_b1c49_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.2%, transparent 15.2%);
# }
# #T_b1c49_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.4%, transparent 14.4%);
# }
# #T_b1c49_row37_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.5%, transparent 13.5%);
# }
# #T_b1c49_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.7%, transparent 12.7%);
# }
# #T_b1c49_row39_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.5%, transparent 11.5%);
# }
# #T_b1c49_row40_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
# }
# #T_b1c49_row41_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.4%, transparent 5.4%);
# }
# #T_b1c49_row42_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.0%, transparent 4.0%);
# }
# #T_b1c49_row43_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.8%, transparent 2.8%);
# }
# #T_b1c49_row44_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_b1c49_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Weekly_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1c49_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_b1c49_row0_col0" class="data row0 col0" >29508.301592</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_b1c49_row1_col0" class="data row1 col0" >29161.210415</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_b1c49_row2_col0" class="data row2 col0" >28784.851727</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_b1c49_row3_col0" class="data row3 col0" >27355.136891</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_b1c49_row4_col0" class="data row4 col0" >26898.070031</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_b1c49_row5_col0" class="data row5 col0" >26332.303819</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_b1c49_row6_col0" class="data row6 col0" >24826.984536</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_b1c49_row7_col0" class="data row7 col0" >21913.243624</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_b1c49_row8_col0" class="data row8 col0" >21710.543621</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row9" class="row_heading level0 row9" >39</th>
#       <td id="T_b1c49_row9_col0" class="data row9 col0" >21000.763562</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row10" class="row_heading level0 row10" >19</th>
#       <td id="T_b1c49_row10_col0" class="data row10 col0" >20362.126734</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row11" class="row_heading level0 row11" >23</th>
#       <td id="T_b1c49_row11_col0" class="data row11 col0" >19776.180881</td>
#     </tr>
#     <tr>
#       <th id="T_b1c49_level0_row12" class="row_heading level0 row12" >31</th>
#       <td id="T_b1c49_row12_col0" class="data row12 col0" >19681.907464</td>
#     </tr>
#     <tr>
#       <th id="T_b1

# %%
len(df.Store.unique())
# Out:
# 45

# %%
df.corr()
# Out:
#                  Store      Dept  Weekly_Sales  IsHoliday  Temperature  \
# Store         1.000000  0.024004     -0.085195  -0.000548    -0.050097
# Dept          0.024004  1.000000      0.148032   0.000916     0.004437
# Weekly_Sales -0.085195  0.148032      1.000000   0.012774    -0.002312
# IsHoliday    -0.000548  0.000916      0.012774   1.000000    -0.155949
# Temperature  -0.050097  0.004437     -0.002312  -0.155949     1.000000
# Fuel_Price    0.065290  0.003572     -0.000120  -0.078281     0.143859
# MarkDown1    -0.119588 -0.002426      0.085251  -0.035586    -0.040594
# MarkDown2    -0.035173  0.000290      0.024130   0.334818    -0.323927
# MarkDown3    -0.031556  0.001784      0.060385   0.427960    -0.096880
# MarkDown4    -0.009941  0.004257      0.045414  -0.000562    -0.063947
# MarkDown5    -0.026634  0.000109      0.090362  -0.053719    -0.017544
# CPI          -0.211088 -0.007477     -0.020921  -0.001944     0.182112
# Unemployment  0.208552  0.007837     -0.025864   0.010460     0.096730
# Size         -0.182881 -0.002966      0.243828   0.000593    -0.058313
# week          0.001031  0.000882      0.027673   0.128184     0.236276
# year          0.002997  0.003738     -0.010111  -0.056746     0.065814
#
#               Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# Store           0.065290  -0.119588  -0.035173  -0.031556  -0.009941
# Dept            0.003572  -0.002426   0.000290   0.001784   0.004257
# Weekly_Sales   -0.000120   0.085251   0.024130   0.060385   0.045414
# IsHoliday      -0.078281  -0.035586   0.334818   0.427960  -0.000562
# Temperature     0.143859  -0.040594  -0.323927  -0.096880  -0.063947
# Fuel_Price      1.000000   0.061371  -0.220895  -0.102092  -0.044986
# MarkDown1       0.061371   1.000000   0.024486  -0.108115   0.819238
# MarkDown2      -0.220895   0.024486   1.000000  -0.050108  -0.007768
# MarkDown3      -0.102092  -0.108115  -0.050108   1.000000  -0.071095
# MarkDown4      -0.044986   0.819238  -0.007768  -0.071095   1.000000
# MarkDown5      -0.128065   0.160257  -0.007440  -0.026467   0.107792
# CPI            -0.164210  -0.055558  -0.039534  -0.023590  -0.049628
# Unemployment   -0.033853   0.050285   0.020940   0.012818   0.024963
# Size            0.003361   0.345673   0.108827   0.048913   0.168196
# week           -0.031140  -0.198076  -0.000995   0.196307  -0.218477
# year            0.779633   0.141332  -0.222109  -0.319162   0.126469
#
#               MarkDown5       CPI  Unemployment      Size      week      year
# Store         -0.026634 -0.211088      0.208552 -0.182881  0.001031  0.002997
# Dept           0.000109 -0.007477      0.007837 -0.002966  0.000882  0.003738
# Weekly_Sales   0.090362 -0.020921     -0.025864  0.243828  0.027673 -0.010111
# IsHoliday     -0.053719 -0.001944      0.010460  0.000593  0.128184 -0.056746
# Temperature   -0.017544  0.182112      0.096730 -0.058313  0.236276  0.065814
# Fuel_Price    -0.128065 -0.164210     -0.033853  0.003361 -0.031140  0.779633
# MarkDown1      0.160257 -0.055558      0.050285  0.345673 -0.198076  0.141332
# MarkDown2     -0.007440 -0.039534      0.020940  0.108827 -0.000995 -0.222109
# MarkDown3     -0.026467 -0.023590      0.012818  0.048913  0.196307 -0.319162
# MarkDown4      0.107792 -0.049628      0.024963  0.168196 -0.218477  0.126469
# MarkDown5      1.000000  0.060630     -0.003843  0.304575  0.084874 -0.128387
# CPI            0.060630  1.000000     -0.299953 -0.003314  0.006342  0.074544
# Unemployment  -0.003843 -0.299953      1.000000 -0.068238 -0.015490 -0.237161
# Size           0.304575 -0.003314     -0.068238  1.000000 -0.001292 -0.004975
# week           0.084874  0.006342     -0.015490 -0.001292  1.000000 -0.181797
# year          -0.128387  0.074544     -0.237161 -0.004975 -0.181797  1.000000

# %%
corr = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr, annot=True,cmap='magma',center=None)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Store'),
#   Text(0, 1.5, 'Dept'),
#   Text(0, 2.5, 'Weekly_Sales'),
#   Text(0, 3.5, 'IsHoliday'),
#   Text(0, 4.5, 'Temperature'),
#   Text(0, 5.5, 'Fuel_Price'),
#   Text(0, 6.5, 'MarkDown1'),
#   Text(0, 7.5, 'MarkDown2'),
#   Text(0, 8.5, 'MarkDown3'),
#   Text(0, 9.5, 'MarkDown4'),
#   Text(0, 10.5, 'MarkDown5'),
#   Text(0, 11.5, 'CPI'),
#   Text(0, 12.5, 'Unemployment'),
#   Text(0, 13.5, 'Size'),
#   Text(0, 14.5, 'week'),
#   Text(0, 15.5, 'year')])

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),vmin=0.01,linecolor="black",linewidth=2, cmap="Greens",center=None, annot=True)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()
